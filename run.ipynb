# %%
import pandas as pd

# %%
# 데이터 가져오기
train_df = pd.read_csv('./data/train.csv')
test_df = pd.read_csv('./data/test.csv')

# %%
from service.preprocessing import preprocessing

df_features, df_target, test_df = preprocessing(train_df, test_df)

# %%
from service.model import base_model

model = base_model(df_features, df_target)
# Out:
# Accuracy: 0.6870
# AUC: 0.6919
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.70      0.90      0.79      1270
#            1       0.65      0.31      0.42       730
#
#     accuracy                           0.69      2000
#    macro avg       0.67      0.61      0.60      2000
# weighted avg       0.68      0.69      0.65      2000

# %%
from service.utils import feature_importance

feature_importance(model, df_features)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 3
#       1 from service.utils import feature_importance
# ----> 3 feature_importance(model, df_features)
#
# File c:\dev\ML\prediction-of-default\service\utils.py:54, in feature_importance(model, X)
#      52 plt.title("Feature Importance")
#      53 plt.bar(range(X.shape[1]), importances[indices], align='center')
# ---> 54 plt.xticks(range(X.shape[1]), X.columns[indices], rotation=90)
#      55 plt.xlim([-1, X.shape[1]])
#      56 plt.show()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'columns'

# %%
from service.utils import make_submit

make_submit(test_df, model)
