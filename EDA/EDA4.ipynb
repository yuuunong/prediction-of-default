# %%
import pandas as pd

# %%
df = pd.read_csv('../data/train.csv')

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import koreanize_matplotlib

sns.histplot(df['신용 점수'])
# Out:
# <Axes: xlabel='신용 점수', ylabel='Count'>

# %%
df['신용카드 발급 가능자'] = df['신용 점수'].apply(lambda x: 1 if x >= 645 else 0)
df['미소금융 등 대상자'] = df['신용 점수'].apply(lambda x: 1 if x <= 749 else 0)
df['중금리 대출시 신용공여한도 우대'] = df['신용 점수'].apply(lambda x: 1 if x <= 879 else 0)
df['구속성 영업행위 금지'] = df['신용 점수'].apply(lambda x: 1 if x <= 724 else 0)

# %%
sns.histplot(df['신용카드 발급 가능자'])
# Out:
# <Axes: xlabel='신용카드 발급 가능자', ylabel='Count'>

# %%
sns.histplot(df['미소금융 등 대상자'])
# Out:
# <Axes: xlabel='미소금융 등 대상자', ylabel='Count'>

# %%
sns.histplot(df['구속성 영업행위 금지'])
# Out:
# <Axes: xlabel='구속성 영업행위 금지', ylabel='Count'>

# %%
sns.histplot(df['최대 신용한도'])
# Out:
# <Axes: xlabel='최대 신용한도', ylabel='Count'>

# %%
sum(df['최대 신용한도'] == 0) / len(df)
# Out:
# 0.0388

# %%
len(df)
# Out:
# 10000
